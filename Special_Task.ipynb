# %% [markdown]
# <a href="https://colab.research.google.com/github/bharatikasture573-cyber/Car_Datasets/blob/main/Special_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./car_dataset.csv")
df
# Out:
#      car_id    brand      model variant fuel_type  engine_cc  mileage_kmpl  \
# 0         1   Toyota  Model_899      V4    Petrol       2490         19.17
# 1         2     Tata  Model_701      V2  Electric       1205         12.45
# 2         3  Hyundai  Model_776      V2  Electric       2321         17.70
# 3         4     Tata  Model_774      V1    Petrol       2441         24.38
# 4         5      Kia  Model_856      V1    Petrol       1570         20.64
# ..      ...      ...        ...     ...       ...        ...           ...
# 995     996   Toyota  Model_159      V2  Electric       2626         20.29
# 996     997   Maruti  Model_271      V2  Electric       2168         21.76
# 997     998    Honda  Model_453      V4    Petrol       2498         10.36
# 998     999     Tata  Model_856      V5    Diesel       1194         11.00
# 999    1000  Hyundai  Model_722      V5  Electric       1060         14.14
#
# ...

# %%
df.head()
# Out:
#    car_id    brand      model variant fuel_type  engine_cc  mileage_kmpl  \
# 0       1   Toyota  Model_899      V4    Petrol       2490         19.17
# 1       2     Tata  Model_701      V2  Electric       1205         12.45
# 2       3  Hyundai  Model_776      V2  Electric       2321         17.70
# 3       4     Tata  Model_774      V1    Petrol       2441         24.38
# 4       5      Kia  Model_856      V1    Petrol       1570         20.64
#
#      price   color  year  ... accessories_cost extended_warranty  \
# 0  1852981    Blue  2024  ...             9534               Yes
# 1  1847906   Black  2025  ...            45814               Yes
# 2  1792525    Grey  2023  ...            36389               Yes
# 3  1542444  Silver  2022  ...            28253                No
# 4  1369388   White  2022  ...            14465               Yes
#
#   roadside_assistance insurance_type  user_reviews  user_rating  \
# 0                  No  Comprehensive           393         4.62
# ...

# %%
df.tail()
# Out:
#      car_id    brand      model variant fuel_type  engine_cc  mileage_kmpl  \
# 995     996   Toyota  Model_159      V2  Electric       2626         20.29
# 996     997   Maruti  Model_271      V2  Electric       2168         21.76
# 997     998    Honda  Model_453      V4    Petrol       2498         10.36
# 998     999     Tata  Model_856      V5    Diesel       1194         11.00
# 999    1000  Hyundai  Model_722      V5  Electric       1060         14.14
#
#        price   color  year  ... accessories_cost extended_warranty  \
# 995   736903  Silver  2022  ...            34470                No
# 996   981305   White  2025  ...            24439               Yes
# 997   835083   Black  2022  ...            29519                No
# 998  1131582    Blue  2016  ...            31124                No
# 999  1956701   White  2023  ...            21927               Yes
#
#     roadside_assistance insurance_type  user_reviews  user_rating  \
# ...

# %%
df.sample(10)
# Out:
#      car_id    brand      model variant fuel_type  engine_cc  mileage_kmpl  \
# 604     605    Honda  Model_152      V5    Petrol       2605         12.10
# 645     646     Tata  Model_309      V3  Electric       2945         22.34
# 904     905  Hyundai  Model_105      V5  Electric        913         12.11
# 587     588   Toyota  Model_505      V4    Diesel       2320         10.04
# 677     678     Tata  Model_579      V2  Electric       1159         17.41
# 253     254   Maruti  Model_923      V5    Diesel        803         14.03
# 698     699     Tata  Model_330      V5    Petrol       1630         15.91
# 239     240    Honda  Model_724      V5    Petrol       1796         22.05
# 732     733   Toyota  Model_698      V5    Diesel       1518         12.40
# 905     906     Tata  Model_663      V3    Petrol        995         22.79
#
#        price   color  year  ... accessories_cost extended_warranty  \
# 604  1927111  Silver  2018  ...            14445               Yes
# ...

# %%
print("Rows and Columns :", df.shape)
# Out:
# Rows and Columns : (1000, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 79 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_id               1000 non-null   int64
#  1   brand                1000 non-null   object
#  2   model                1000 non-null   object
#  3   variant              1000 non-null   object
#  4   fuel_type            1000 non-null   object
#  5   engine_cc            1000 non-null   int64
#  6   mileage_kmpl         1000 non-null   float64
#  7   price                1000 non-null   int64
#  8   color                1000 non-null   object
#  9   year                 1000 non-null   int64
#  10  transmission         1000 non-null   object
#  11  owner_type           1000 non-null   object
#  12  registration_state   1000 non-null   object
#  13  insurance_status     1000 non-null   object
#  14  seating_capacity     1000 non-null   int64
# ...

# %%
print(df.columns)
# Out:
# Index(['car_id', 'brand', 'model', 'variant', 'fuel_type', 'engine_cc',
#        'mileage_kmpl', 'price', 'color', 'year', 'transmission', 'owner_type',
#        'registration_state', 'insurance_status', 'seating_capacity',
#        'max_power_bhp', 'torque_nm', 'fuel_tank_capacity', 'top_speed',
#        'weight_kg', 'boot_space', 'ground_clearance', 'wheelbase', 'airbags',
#        'abs', 'traction_control', 'cruise_control', 'sunroof',
#        'infotainment_system', 'navigation', 'bluetooth', 'usb_ports',
#        'climate_control', 'rear_ac', 'parking_sensors', 'parking_camera',
#        'headlight_type', 'tail_light_type', 'wheel_type', 'tyre_type',
#        'battery_type', 'range_km', 'charging_time', 'service_cost',
#        'warranty_years', 'rating', 'launch_country', 'emission_norm',
#        'odometer', 'insurance_cost', 'registration_cost', 'road_tax',
#        'resale_value', 'availability', 'delivery_time', 'discount_offer',
# ...

# %%
df.dtypes
# Out:
# car_id                int64
# brand                object
# model                object
# variant              object
# fuel_type            object
#                      ...
# user_rating         float64
# popularity_index      int64
# stock_status         object
# launch_year           int64
# discontinued         object
# Length: 79, dtype: object

# %%
df.describe()
# Out:
#             car_id    engine_cc  mileage_kmpl         price         year  \
# count  1000.000000  1000.000000   1000.000000  1.000000e+03  1000.000000
# mean    500.500000  1933.263000     17.528070  1.236199e+06  2019.951000
# std     288.819436   629.930957      4.379798  4.419122e+05     3.166801
# min       1.000000   800.000000     10.040000  5.021910e+05  2015.000000
# 25%     250.750000  1407.750000     13.765000  8.602878e+05  2017.000000
# 50%     500.500000  1922.000000     17.495000  1.226285e+06  2020.000000
# 75%     750.250000  2497.250000     21.340000  1.627011e+06  2023.000000
# max    1000.000000  3000.000000     24.990000  1.999928e+06  2025.000000
#
#        seating_capacity  max_power_bhp    torque_nm  fuel_tank_capacity  \
# count       1000.000000    1000.000000  1000.000000         1000.000000
# mean           5.515000     123.210500   250.500420           44.932000
# std            1.097716      42.917089    86.727341            8.904418
# ...

# %%
df.isnull().sum()
# Out:
# car_id              0
# brand               0
# model               0
# variant             0
# fuel_type           0
#                    ..
# user_rating         0
# popularity_index    0
# stock_status        0
# launch_year         0
# discontinued        0
# Length: 79, dtype: int64

# %%
df.nunique()
# Out:
# car_id              1000
# brand                  7
# model                597
# variant                5
# fuel_type              3
#                     ...
# user_rating          198
# popularity_index     100
# stock_status           2
# launch_year           11
# discontinued           2
# Length: 79, dtype: int64

# %%
#1. Histogram
plt.figure(figsize=(8,5))
plt.hist(df["price"], bins=30)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
# Bar Chart
plt.figure(figsize=(10,6))
df["brand"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Car Brands")
plt.xlabel("Brand")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# Pie chart
plt.figure(figsize=(7,7))
df["fuel_type"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.title("Fuel Type Distribution")
plt.ylabel("")
plt.show()

# %%
# 4. Scatter Plot
plt.figure(figsize=(8,6))
plt.scatter(df["engine_cc"], df["price"])
plt.xlabel("Engine CC")
plt.ylabel("Price")
plt.title("Engine CC vs Price")
plt.show()

# %%
#Box plot
plt.figure(figsize=(8,5))
plt.boxplot(df["price"])
plt.title("Price Boxplot")
plt.show()

# %%
#count Plot
plt.figure(figsize=(10,6))
sns.countplot(data=df, x="fuel_type")
plt.title("Fuel Type Count")
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(15,10))
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap( numeric_df.corr(),annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
